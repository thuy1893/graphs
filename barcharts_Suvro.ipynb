# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("phyla.csv")

# %%
df.head()
# Out:
#                   sample_id  Unassigned  k__Bacteria;p__Actinobacteriota  \
# 0  Control Without Sucrose     0.065332                         1.505001
# 1     Control With Sucrose     0.004298                         2.553009
# 2                 CHX 0.1%     0.000000                         0.488677
# 3                 CHX 0.2%     0.000000                         0.432331
# 4                     ISOWE    0.002534                         0.690057
#
#    k__Bacteria;p__Bacteroidota  k__Bacteria;p__Desulfobacterota  \
# 0                     2.322239                         0.038011
# 1                    11.875358                         0.063037
# 2                     0.748373                         0.023270
# 3                     0.678571                         0.015038
# 4                     4.073617                         0.043920
#
#    k__Bacteria;p__Firmicutes  k__Bacteria;p__Fusobacteriota  \
# 0                  95.533699                       0.005939
# ...

# %%
ax = df.plot.bar(stacked=True, x='sample_id', rot=90, fontsize=10, width=0.85, colormap='Paired') 
#the x='taxon' is to set the column 'taxon' as the lavels on the x-axis.]
#for colormap, see: http://scipy.github.io/old-wiki/pages/Cookbook/Matplotlib/Show_colormaps
ax.invert_yaxis()
plt.legend(bbox_to_anchor=(1.0, 1.0))
#plt.tight_layout()
#ax.figure.savefig('phylum_Suvro.png')
plt.ylabel('Relative abundance (%)')
plt.show()

# %%
genera10 = pd.read_csv("top10_genera.csv")

# %%
genera10.head()
# Out:
#                    sample_id  Lactobacillus  Staphylococcus  Streptococcus  \
# 0  Control Without Sucrose 1          20992             359            860
# 1  Control Without Sucrose 2          19819             418           1533
# 2  Control Without Sucrose 3          21236             454           1291
# 3     Control With Sucrose 1          35184             953            137
# 4     Control With Sucrose 2          35209             897            133
#
#    Porphyromonas  Prevotella  Parvimonas  Phocaeicola  Alloprevotella  \
# 0             55         151         698           73              46
# 1             61         169        1053           84              49
# 2             58         148        1175           89              41
# 3           1101         499          66          508             372
# 4           1540         588          58          498             984
#
#    Pyramidobacter
# 0             713
# 1             925
# 2             520
# ...

# %%
col=["#a5d4f0", "#146899", "#98e090", "#329127", "#fa947f", "#d91821", "#a83707", "#fa6807", "#d192cc"]
ax = genera10.plot.bar(stacked=True, x='sample_id', rot=90, fontsize=10, width=0.85, color=col) #instead of color, could have had colormap='Paired'
#the x='taxon' is to set the column 'taxon' as the lavels on the x-axis.]
#for colormap, see: http://scipy.github.io/old-wiki/pages/Cookbook/Matplotlib/Show_colormaps
#ax.invert_yaxis()
#plt.legend(bbox_to_anchor=(1.0, 1.0))
#plt.tight_layout()
#ax.figure.savefig('phylum_Suvro.png')
current_handles, current_labels = plt.gca().get_legend_handles_labels()
reversed_handles = list(reversed(current_handles))
reversed_labels = list(reversed(current_labels))

# call plt.legend() with the new values
plt.legend(reversed_handles,reversed_labels, bbox_to_anchor=(1, 0.5))

plt.ylabel('Absolute abundance')
plt.show()

# %%
genera10_b = pd.read_csv("top10_genera_noLacto.csv")

# %%
col=["#146899", "#98e090", "#329127", "#fa947f", "#d91821", "#a83707", "#fa6807", "#d192cc","#75076d", "#f2d76b"]
ax = genera10_b.plot.bar(stacked=True, x='sample_id', rot=90, fontsize=10, width=0.85, color=col) 
#the x='taxon' is to set the column 'taxon' as the lavels on the x-axis.]
#for colormap, see: http://scipy.github.io/old-wiki/pages/Cookbook/Matplotlib/Show_colormaps
#ax.invert_yaxis()
#plt.legend(bbox_to_anchor=(1.0, 1.0))
#plt.tight_layout()
#ax.figure.savefig('phylum_Suvro.png')
current_handles, current_labels = plt.gca().get_legend_handles_labels()
reversed_handles = list(reversed(current_handles))
reversed_labels = list(reversed(current_labels))

# call plt.legend() with the new values
plt.legend(reversed_handles,reversed_labels, bbox_to_anchor=(1, 0.5))

plt.ylabel('Absolute abundance')
plt.show()
